# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(
    whale_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_returns = whale_returns.sort_index()
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna().copy()
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(
    algo_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_returns = algo_returns.sort_index()
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns = algo_returns.dropna().copy()
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_history_csv = Path("Resources/sp_tsx_history.csv")
sp_tsx_history = pd.read_csv(
    sp_tsx_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp_tsx_history = sp_tsx_history.sort_index()
sp_tsx_history.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sp_tsx_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_tsx_history["Close"] = sp_tsx_history["Close"].str.replace("$", "")
sp_tsx_history["Close"] = sp_tsx_history["Close"].str.replace(",", "")
sp_tsx_history["Close"] = sp_tsx_history["Close"].astype("float")
sp_tsx_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp_tsx_returns = sp_tsx_history.pct_change()
sp_tsx_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
sp_tsx_returns = sp_tsx_returns.dropna().copy()
sp_tsx_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_returns = sp_tsx_returns.rename(columns={"Close": "S&P TSX"})
sp_tsx_returns.head()
# Out:
#              S&P TSX
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
all_portfolios = pd.concat([whale_returns, algo_returns, sp_tsx_returns], axis="columns", join="inner")
all_portfolios.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P TSX
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# 2015-03-06 -0.011460 -0.009972
# 2015-03-09  0.001303 -0.006555

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_portfolios.plot(figsize=(20, 10), title="Daily Returns")
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + all_portfolios).cumprod()

# Plot cumulative returns
cumulative_returns.plot(figsize=(20, 10), title="Cumulative Returns")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
#all_portfolios.plot.box(figsize=(20, 10), title="Portfolio Risk")
display(all_portfolios)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-25                    -0.005153                0.004848  0.000682
# 2019-04-26                     0.012355                0.010434  0.002981
# 2019-04-29                     0.006251                0.005223  0.005208
# 2019-04-30                    -0.000259               -0.003702 -0.002944
# 2019-05-01                    -0.007936               -0.007833  0.000094
#
#               Algo 2   S&P TSX
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# 2015-03-06 -0.011460 -0.009972
# 2015-03-09  0.001303 -0.006555
# ...              ...       ...
# 2019-04-25 -0.007247 -0.000628
# 2019-04-26  0.005256  0.002254
# 2019-04-29  0.002829 -0.000788
# 2019-04-30 -0.001570 -0.001183
# 2019-05-01 -0.007358 -0.004703
#
# [1029 rows x 7 columns]

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_portfolios.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P TSX                        0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sp_tsx_risk = all_portfolios["S&P TSX"].std()

# Determine which portfolios are riskier than the S&P TSX 60
all_portfolios.std() > sp_tsx_risk
# Out:
# SOROS FUND MANAGEMENT LLC       True
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                          True
# Algo 2                          True
# S&P TSX                        False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
anual_std = all_portfolios.std() * np.sqrt(252)
anual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P TSX                        0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P TSX 60 using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_portfolios_roll_std = all_portfolios.rolling(window=21).std()

# Plot the rolling standard deviation
all_portfolios_roll_std.plot(figsize=(20, 10), title="21 Day Rolling Standard Deviation")
# Out:
# <AxesSubplot:title={'center':'21 Day Rolling Standard Deviation'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
corr_df = all_portfolios.corr()

# Display de correlation matrix
corr_df.style.background_gradient(cmap="bwr")
# Out:
# <style  type="text/css" >
# #T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col0,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col1,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col2,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row3_col3,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row4_col4,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row5_col5,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row6_col6{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col1{
#             background-color:  #ffd2d2;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col2{
#             background-color:  #f4f4ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col3{
#             background-color:  #ffb2b2;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col4{
#             background-color:  #5c5cff;
#             color:  #f1f1f1;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col5{
#             background-color:  #ff7c7c;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col6,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row6_col0{
#             background-color:  #fff2f2;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col0,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row5_col1,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row5_col3{
#             background-color:  #ffe2e2;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col2{
#             background-color:  #a4a4ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col3{
#             background-color:  #b4b4ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col4{
#             background-color:  #4040ff;
#             color:  #f1f1f1;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col5{
#             background-color:  #ffe8e8;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col6{
#             background-color:  #8282ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col0{
#             background-color:  #b8b8ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col1{
#             background-color:  #7474ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col3,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col6{
#             background-color:  #6060ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col4,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row4_col0,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row4_col1,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row4_col2,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row4_col3,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row4_col5,#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row4_col6{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col5{
#             background-color:  #9e9eff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row3_col0{
#             background-color:  #ffbaba;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row3_col1{
#             background-color:  #bebeff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row3_col2{
#             background-color:  #a0a0ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row3_col4{
#             background-color:  #4e4eff;
#             color:  #f1f1f1;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row3_col5{
#             background-color:  #ffe0e0;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row3_col6{
#             background-color:  #b6b6ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row5_col0{
#             background-color:  #ff8080;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row5_col2{
#             background-color:  #d2d2ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row5_col4{
#             background-color:  #4a4aff;
#             color:  #f1f1f1;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row5_col6{
#             background-color:  #ffc2c2;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row6_col1{
#             background-color:  #9898ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row6_col2{
#             background-color:  #aaaaff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row6_col3{
#             background-color:  #c0c0ff;
#             color:  #000000;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row6_col4{
#             background-color:  #5a5aff;
#             color:  #f1f1f1;
#         }#T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row6_col5{
#             background-color:  #ffbcbc;
#             color:  #000000;
#         }</style><table id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >S&P TSX</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col1" class="data row0 col1" >0.697076</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col2" class="data row0 col2" >0.560964</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col3" class="data row0 col3" >0.750181</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col4" class="data row0 col4" >0.313795</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col5" class="data row0 col5" >0.826667</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row0_col6" class="data row0 col6" >0.673930</td>
#             </tr>
#             <tr>
#                         <th id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7level0_row1" class="row_heading level0 row1" >PAULSON & CO.INC. </th>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col0" class="data row1 col0" >0.697076</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col2" class="data row1 col2" >0.433034</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col3" class="data row1 col3" >0.540033</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col4" class="data row1 col4" >0.266363</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col5" class="data row1 col5" >0.674015</td>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row1_col6" class="data row1 col6" >0.486511</td>
#             </tr>
#             <tr>
#                         <th id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7level0_row2" class="row_heading level0 row2" >TIGER GLOBAL MANAGEMENT LLC</th>
#                         <td id="T_c75eedda_ff72_11ea_9fe7_c0b6f9140de7row2_col0" class="data row2 col0" >0.560964</td>
#                         <td id="T_c75eedda_ff72_11ea_9

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
covariance = all_portfolios["BERKSHIRE HATHAWAY INC"].rolling(window=60).cov(all_portfolios["S&P TSX"])

# Calculate variance of S&P TSX
variance = all_portfolios["S&P TSX"].rolling(60).var()

# Computing beta
beta = covariance / variance

# Plot beta trend
beta.plot(figsize=(20, 10), title="Berkshire Hathaway Inc. Beta")
# Out:
# <AxesSubplot:title={'center':'Berkshire Hathaway Inc. Beta'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
all_portfolios.ewm(halflife=21).std().plot(figsize=(20, 10), title="Exponentially Weighted Average")
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (all_portfolios.mean() * 252) / (all_portfolios.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# S&P TSX                        0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
shop_historical_csv = Path("Resources/shop_historical.csv")
shop_historical = pd.read_csv(
    shop_historical_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
shop_historical = shop_historical.sort_index()
shop_historical.head()
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
# Reading data from 2nd stock
otex_historical_csv = Path("Resources/otex_historical.csv")
otex_historical = pd.read_csv(
    otex_historical_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
otex_historical = otex_historical.sort_index()
otex_historical.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02   OTEX  43.58
# 2018-01-03   OTEX  43.07
# 2018-01-04   OTEX  42.91
# 2018-01-05   OTEX  42.57
# 2018-01-08   OTEX  42.16

# %%
# Reading data from 3rd stock
l_historical_csv = Path("Resources/l_historical.csv")
l_historical = pd.read_csv(
    l_historical_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
l_historical = l_historical.sort_index()
l_historical.head()
# Out:
#            Symbol  Close
# Date
# 2018-01-02      L  57.99
# 2018-01-03      L  57.41
# 2018-01-04      L  57.42
# 2018-01-05      L  57.42
# 2018-01-08      L  56.86

# %%
# Combine all stocks in a single DataFrame
all_stocks = pd.concat([shop_historical, otex_historical, l_historical], axis="rows", join="inner")
all_stocks.head()
# Out:
#            Symbol   Close
# Date
# 2018-01-02   SHOP  132.06
# 2018-01-03   SHOP  135.15
# 2018-01-04   SHOP  137.46
# 2018-01-05   SHOP  137.26
# 2018-01-08   SHOP  139.51

# %%
# Reset Date index
all_stocks = all_stocks.reset_index()
all_stocks.head()
# Out:
#         Date Symbol   Close
# 0 2018-01-02   SHOP  132.06
# 1 2018-01-03   SHOP  135.15
# 2 2018-01-04   SHOP  137.46
# 3 2018-01-05   SHOP  137.26
# 4 2018-01-08   SHOP  139.51

# %%
# Reorganize portfolio data by having a column per symbol
portfolio = all_stocks.pivot_table(values="Close", index="Date", columns="Symbol")
portfolio.head()
# Out:
# Symbol          L   OTEX    SHOP
# Date
# 2018-01-02  57.99  43.58  132.06
# 2018-01-03  57.41  43.07  135.15
# 2018-01-04  57.42  42.91  137.46
# 2018-01-05  57.42  42.57  137.26
# 2018-01-08  56.86  42.16  139.51

# %%
# Calculate daily returns
daily_returns = portfolio.pct_change()

# Drop NAs
daily_returns = daily_returns.dropna().copy()

# Display sample data
daily_returns.head()
# Out:
# Symbol             L      OTEX      SHOP
# Date
# 2018-01-03 -0.010002 -0.011703  0.023398
# 2018-01-04  0.000174 -0.003715  0.017092
# 2018-01-05  0.000000 -0.007924 -0.001455
# 2018-01-08 -0.009753 -0.009631  0.016392
# 2018-01-09  0.008969 -0.000712 -0.011254

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = daily_returns.dot(weights)

# Display sample data
portfolio_returns.head()
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

all_portfolios["Custom"] = portfolio_returns
all_portfolios.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-25                    -0.005153                0.004848  0.000682
# 2019-04-26                     0.012355                0.010434  0.002981
# 2019-04-29                     0.006251                0.005223  0.005208
# 2019-04-30                    -0.000259               -0.003702 -0.002944
# 2019-05-01                    -0.007936               -0.007833  0.000094
#
#               Algo 2   S&P TSX    Custom
# Date
# 2019-04-25 -0.007247 -0.000628  0.003461
# 2019-04-26  0.005256  0.002254  0.003243
# 2019-04-29  0.002829 -0.000788  0.003303
# 2019-04-30 -0.001570 -0.001183  0.026937
# 2019-05-01 -0.007358 -0.004703 -0.000079

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_portfolios = all_portfolios.dropna().copy()

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
risk = all_portfolios.std() * np.sqrt(252)
risk
# Out:
# SOROS FUND MANAGEMENT LLC      0.145675
# PAULSON & CO.INC.              0.114343
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# BERKSHIRE HATHAWAY INC         0.227445
# Algo 1                         0.120028
# Algo 2                         0.137664
# S&P TSX                        0.099121
# Custom                         0.224346
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_std_dev = all_portfolios.rolling(window=21).std()

# Plot rolling standard deviation
rolling_std_dev.plot(figsize=(20, 10), title="21 Day Rolling Standard Deviation")
# Out:
# <AxesSubplot:title={'center':'21 Day Rolling Standard Deviation'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

df = all_portfolios.corr()
df.style.background_gradient(cmap="hot")
# Out:
# <style  type="text/css" >
# #T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col0,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col1,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col2,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col3,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col4,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col5,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col6,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col7{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col1{
#             background-color:  #ffc200;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col2{
#             background-color:  #ff3c00;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col3,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col3{
#             background-color:  #ffdc00;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col4{
#             background-color:  #900000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col5{
#             background-color:  #ffff0b;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col6{
#             background-color:  #ff8300;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col7{
#             background-color:  #ff2f00;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col0{
#             background-color:  #ffc700;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col2{
#             background-color:  #ff4400;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col3,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col3,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col3{
#             background-color:  #ff5c00;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col4,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col7,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col6{
#             background-color:  #9b0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col5,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col1{
#             background-color:  #ffe100;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row1_col6{
#             background-color:  #ff4900;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col0,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col1{
#             background-color:  #df0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col3{
#             background-color:  #5f0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col4,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col0,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col1,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col2,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col3,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col5,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col6,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row4_col7{
#             background-color:  #0b0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col5{
#             background-color:  #ab0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row2_col7{
#             background-color:  #570000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col0{
#             background-color:  #ffd700;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col1{
#             background-color:  #ff4f00;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col2{
#             background-color:  #cd0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col4{
#             background-color:  #890000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col5{
#             background-color:  #ffd400;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col6{
#             background-color:  #ff6100;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row3_col7{
#             background-color:  #ff7e00;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col0{
#             background-color:  #ffff0f;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col2{
#             background-color:  #ff1d00;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col4{
#             background-color:  #9e0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col6{
#             background-color:  #ffc500;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row5_col7{
#             background-color:  #ff3400;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col0{
#             background-color:  #ff7b00;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col1{
#             background-color:  #ff3700;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col2{
#             background-color:  #f70000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col4{
#             background-color:  #810000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col5{
#             background-color:  #ffb700;
#             color:  #000000;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row6_col7{
#             background-color:  #ff4100;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col0{
#             background-color:  #fc0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col1,#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col4{
#             background-color:  #4a0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col2{
#             background-color:  #8e0000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col5{
#             background-color:  #f90000;
#             color:  #f1f1f1;
#         }#T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row7_col6{
#             background-color:  #ff1f00;
#             color:  #f1f1f1;
#         }</style><table id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >S&P TSX</th>        <th class="col_heading level0 col7" >Custom</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col1" class="data row0 col1" >0.764174</td>
#                         <td id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col2" class="data row0 col2" >0.526710</td>
#                         <td id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col3" class="data row0 col3" >0.782414</td>
#                         <td id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col4" class="data row0 col4" >0.305525</td>
#                         <td id="T_c7fc06e2_ff72_11ea_b6f7_c0b6f9140de7row0_col5" class="data row0 col

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
covariance = all_portfolios["Custom"].rolling(window=60).cov(all_portfolios["S&P TSX"])
variance = all_portfolios["S&P TSX"].rolling(60).var()
beta = (covariance / variance)
beta.plot(figsize=(20, 10), title="Custom Portfolio Beta")
# Out:
# <AxesSubplot:title={'center':'Custom Portfolio Beta'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratios = (all_portfolios.mean() * 252) / (all_portfolios.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC     -0.088196
# PAULSON & CO.INC.             -0.396282
# TIGER GLOBAL MANAGEMENT LLC   -1.391612
# BERKSHIRE HATHAWAY INC         0.195907
# Algo 1                         1.901461
# Algo 2                         0.021394
# S&P TSX                        0.034651
# Custom                         1.564547
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
